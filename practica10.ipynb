# %%
#espacios en blanco
nombre = input("Cual es tu nombre")
edad = input("Que edad tienes")
profesion = input("Que deseas estudiar")

print("mi nombre es",nombre)
print("tengo" ,edad )
print("me gustaria ser" ,profesion)
# Out:
# Cual es tu nombre negro
# Que edad tienes 199
# Que deseas estudiar 1
# mi nombre es negro
# tengo 199
# me gustaria ser 1

# %%
nombre = input("cual es tu nombre")
apellido = input("cual es tu apellido")
print(nombre[::-1] ,apellido[::-1])
# Out:
# cual es tu nombre hu
# cual es tu apellido no
# uh on

# %%
edad = int(input("cuantos años tienes"))
nombre = input("como te llamas")
print("en 100 años tendras" ,edad+100)
# Out:
# cuantos años tienes 12
# como te llamas ji
# en 100 años tendras 112

# %%
num = int(input("Número para factorial: "))
print("Factorial:", math.factorial(num))

num = input("Número para suma de dígitos: ")
print("Suma de dígitos:", sum(map(int, num)))

m = int(input("Número para el patrón: "))
for i in range(1, m + 1):
    print(''.join(str(j) for j in range(1, i + 1)))
for i in range(m, 0, -1):
    print('*' * i)

numeros = list(map(int, input("10 números separados por comas: ").split(',')))
print("Promedio:", sum(numeros) / len(numeros))

a, b = map(int, input("Dos números separados por espacio: ").split())
print("Números primos entre", a, "y", b, ":")
for num in range(a, b + 1):
    if num > 1 and all(num % i != 0 for i in range(2, int(num**0.5) + 1)):
        print(num)
