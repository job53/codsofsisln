# %%
ciudad = input("escribe el nombre de la ciudad")
ciudades=["delhi","paris","nueva_york","rio_de_janeiro"]
monumentos=["red_ford","torre_eifel","estatua_de_la_libertad","cristo_redentor"]
print("el monumento es",monumentos[ciudades.index(ciudad)])
# Out:
# escribe el nombre de la ciudad paris
# el monumento es torre_eifel

# %%
edad = int(input("escribe tu edad"))
if edad>18:
    print("el puede votar")
elif edad<18:
    print("no puede votar")
# Out:
# escribe tu edad 12
# no puede votar

# %%
numeroA = int(input("escribe el numero"))
numeroB = int(input("escribe el numero"))
if numeroA>numeroB:
    print("numeroaA es mayor")
elif numeroA<numeroB:
    print("numeroB es menor")
# Out:
# escribe el numero 90
# escribe el numero 7
# numeroaA es mayor

# %%
edad=[]
persona_A = int(input("escribe tu edad"))
edad.append(persona_A)
persona_B = int(input("escribe tu edad"))
edad.append(persona_B)
persona_C = int(input("escribe tu edad"))
edad.append(persona_C)
persona_D = int(input("escribe tu edad"))
edad.append(persona_D)
print(edad)
print("tas chiquito",min(edad))
# Out:
# escribe tu edad 244
# escribe tu edad 1
# escribe tu edad 20
# escribe tu edad 90
# [244, 1, 20, 90]
# tas chiquito 1

# %%
import string
palabra = input("escribe tu palabra")
letras= list(palabra)
mayus = string.ascii_uppercase
minus = string.ascii_lowercase
print(letras)
for i in letras:
    if i in mayus:
        print("mayuscula",i)
    elif i in minus:
        print("minuscula",i)
    else:
    print(("es un simbolo o un numero
# Out:
# escribe tu palabra Tetas
# ['T', 'e', 't', 'a', 's']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 8
#       6 print(letras)
#       7 for i in letras:
# ----> 8     print(letras[i])
#
# TypeError: list indices must be integers or slices, not str
